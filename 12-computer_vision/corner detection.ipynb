# %%
import numpy as np
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# a corner is a point where the pic changes sharply in every direction the harris corner detector finds these points by cheaking how much a small window chnges when moved slightly.what harris detector the harris detctor takes a small square and slides it over the image for each position it cheaks "if move this slightly in any direction does tyhe image vhange a lot?!
#
# if no chnage-flat area
#
# if cgnage only in all direction - edge
#
# if change in all directions - corner
#
# the places with strong change in all directions are markedas cornes9 why corners are useful?
#
# beacuse they are:
#
# unique points
#
# easy to match betwwen images
#
# hlepful for tracking,stitchnf,mapping,etc

# %%
flat_chess=cv2.imread("c:/Data-Science/12-computer_vision/DATA/DATA/flat_chessboard.png")
flat_chess=cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)
plt.imshow(flat_chess)

# %%
gray_flat_chess=cv2.cvtColor(flat_chess,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_flat_chess,cmap="gray")

# %%
real_chess=cv2.imread("c:/Data-Science/12-computer_vision/DATA/DATA/real_chessboard.jpg")
real_chess=cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)
plt.imshow(real_chess)

# %%
gray_real_chess=cv2.cvtColor(real_chess,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_real_chess,cmap="gray")

# %% [markdown]
# dst=cv2cornerarris(src=gray.blocksize=2,ksize=3,k=0.04)
#
# what cv2cornerharris()soes
#
# cornerharris is a corner detction algo tht finds points in an image where the intensity
# chnages shrply in two direction(like corners os a building,chessboard corners,etc)
#
# it outputs an image (dst) where high values indicate corers parameter bu parameter explanation
#
# 1.src=gray the input image.must be grayscale and float32.example:graynp.float32(gray)
# 2.blocksize=2 size of the nieghborhod window(nxn) around ach pixel.harris dettctor looks inside tis window o caculate corner strength.this of it as :"how big of an area around each pixel should i examine to decie if its corner?
#
# 3.ksize=3

# %%
#convert gray scale image to float values
gray=np.float32(gray_flat_chess)

'''
gray_flat_chess: this is assumed to be the grayscale version of the input
image. grayscale images have pixl values ranging from 1 to 255.
np.float32(gray_chess_chess): this converts the grayscale image into a float32
data type. this is necessary becuse the harris corner detection algorithm
requires floating-point precision to perform accurate computations.
'''

#corner harris detection
dst=cv2.cornerHarris(src=gray,blockSize=2,ksize=3,k=0.04)
'''
cv2.cornerHarris(): this function detects corners in the grayscale image using the 
src=gray:the source image,which is the grayscale image converted to float
vlaues.
blocksize=2: this is the size of the neighborhood cosidered for corner
detetction. a smaller value focuses on more loval features
ksize=3: the aperture parameter of the sobel derivative
used in the compuation.
it determines the size of the window for the derivative calculation.
k=0.04: harris detector free parameter,
uesd to separtae corner-like responses from edge-like responses
'''

#result is dilated for marking the corners not important to actualconer detction
#this is just so we can plot out the points on the image shown
dst=cv2.dilate(dst,None)
'''
cv2.dialte():this function dilates(expands) the areas around detected
corners.Dialtes is not necessary for detecting the corners
but is often to make the detcted points more visible when plotting
'''
#threshold for an optional value,it may vary depending on the image
flat_chess[dst>0.01*dst.max()]=[255,0,0]

plt.imshow(flat_chess)

# %%
#convert gray scale in=mage to float values
gray=np.float32(gray_real_chess)

#corner harris detection
dst=cv2.cornerHarris(src=gray,blockSize=2,ksize=3,k=0.04)

#result is dialted for making the corners not important to actual corner detection
#this is just so we can plot out the points on tthe image shwn
dst-cv2.dilate(dst,None)

#threshold for an optinl value,it may vary depending on the image
real_chess[dst>0.01*dst.max()]=[255,0,0]

plt.imshow(real_chess)
