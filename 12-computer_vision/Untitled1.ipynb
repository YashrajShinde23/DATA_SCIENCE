# %%
# !pip install ultralytics==8.0.0
# Out:
# ...
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002A5887D9E10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /simple/ultralytics/
#   Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002A5887D9A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /simple/ultralytics/
#   Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002A5887D9CF8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /simple/ultralytics/
# ...

# %%
 'python -m pip install --upgrade pip'
# Out:
# 'python -m pip install --upgrade pip'

# %%
# !pip install ultralytics==8.0.0
# Out:
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000001253B628E10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /simple/ultralytics/
#   Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000001253B628CF8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /simple/ultralytics/
#   Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000001253B628208>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /simple/ultralytics/
# ...
