# %% [markdown]
# # number of layers
# what it is:
# how deep your model is(how many hidden layers)
#
# meaning:
# more layers->can learn more complex patterns
# too many->mat cause overfitting or vanishing gradients
#
# examples:
# cnn for

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#create simple dataset: y=2x+1

x=np.linspace(-1,1,100).reshape(-1,1)
y=2*x+1

# %%
# activation function(relu)
def relu(z):
    return np.maximum(0,z)

# %%
#forward pass for diefferent number of layers

def forward(x,weights,biases):
    a=x
    for W,b in zip(weights[:-1],biases[:-1]): #hidden layers
        a=relu(a @ W+b)
    #output layers(linear)
    return a @ weights[-1] + biases[-1]

# %%
#plot loss vs epochs
plt.figure(figsize=(10,6))

for L in layer_options:
    plt.plot(results[L],label=f"{L} Hidden layers")
    
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("effect of numbeer of layers on learning (simple simulation )")
plt.legend()
plt.grid(True)
plt.show()
